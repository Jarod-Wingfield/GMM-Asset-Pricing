# %%
################################################
# GMM - Asset Pricing
# Author: Jiaying Wu
# Date: Oct. 2024
################################################

from GMM_SDF import GMM_Two_Stage
import pandas as pd

# %%
# Table display options
pd.options.display.float_format = '{:.3f}'.format
pd.set_option('display.max_columns', None)

# %%
# Load data (already design/set up in the .py file)
core=GMM_Two_Stage(data_path="")

core.data()
# Out:
# Sample Time Period: 720
# Test Assets: 25
# All Factors: 6

# %%
Table1,Table2=core.Price_of_risk(regs=[['Mkt-RF'],['Mkt-RF','SMB','HML'],['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']],newey_west_adj=True,nlags=3)
print("Price of risk (return in percentage)")
print(Table1)
# Out:
# Price of risk (return in percentage)
#                       (1)         (2)         (3)
# Mkt-RF         0.039(***)  0.043(***)  0.052(***)
# [std]               0.009       0.009       0.011
# SMB                           0.016()  0.054(***)
# [std]                           0.012       0.014
# HML                        0.058(***)    -0.012()
# [std]                           0.015       0.032
# RMW                                    0.179(***)
# [std]                                       0.036
# CMA                                     0.125(**)
# [std]                                       0.058
#
# SSQE(%)           179.085     294.432      75.550
# MAPE(%)            19.060      30.988      14.558
# J statistic       105.922      91.223      48.576
# J-Test pvalue       0.000       0.000       0.000

# %%
print("Pricing error")
Table2
# Out:
# Pricing error
#                SMALL LoBM     ME1 BM2      ME1 BM3   ME1 BM4 SMALL HiBM  \
# Alpha_model1  -0.835(***)    -0.206()     -0.117()   0.123()    0.232()
# [std]               0.274       0.209        0.189     0.186      0.222
# ---
# Alpha_model2  -0.765(***)  -0.285(**)  -0.323(***)  -0.183()   -0.187()
# [std]               0.196       0.132        0.124     0.126      0.147
# ---
# Alpha_model3      -0.04()     0.264()     -0.023()    0.07()    0.004()
# [std]               0.253       0.245        0.139     0.174      0.140
# ---
#
#                   ME2 BM1     ME2 BM2    ME2 BM3      ME2 BM4      ME2 BM5  \
# Alpha_model1  -0.578(***)    -0.165()   -0.012()      0.058()      0.068()
# [std]               0.204       0.168      0.155        0.146        0.182
# ---
# Alpha_model2   -0.45(***)  -0.267(**)  -0.24(**)  -0.263(***)  -0.384(***)
# [std]               0.133       0.112      0.108        0.096        0.129
# ---
# ...

# %%
Table3=core.Risk_exposure(regs=[['Mkt-RF'],['Mkt-RF','SMB','HML'],['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']],newey_west_adj=True,nlags=3)

print("Risk Exposure")
# print(Table3)
# Out:
# Risk Exposure

# %%
Table3
# Out:
#                                  SMALL LoBM      ME1 BM2     ME1 BM3  \
# Factors:Mkt-RF
# Beta Mkt-RF                      1.412(***)   1.222(***)  1.105(***)
# [std]                                 0.042        0.039       0.037
# Alpha                             -0.352(*)      0.029()    -0.041()
# [std]                                 0.182        0.159       0.128
# ---
# Factors:Mkt-RF,SMB,HML
# Beta Mkt-RF                      1.081(***)   0.948(***)  0.916(***)
# [std]                                 0.025        0.022       0.013
# Beta SMB                         1.401(***)   1.314(***)  1.094(***)
# [std]                                 0.044        0.065       0.021
# Beta HML                        -0.485(***)  -0.196(***)  0.116(***)
# [std]                                 0.047        0.051       0.019
# Alpha                             -0.169(*)      0.113()    -0.024()
# [std]                                 0.090        0.069       0.047
# ---
# ...
